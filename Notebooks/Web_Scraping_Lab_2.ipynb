# %%
#import libraries
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import matplotlib.pyplot as plt
import time
import csv
from datetime import datetime

# %%
url = "https://books.toscrape.com/"

# %%
header = ["Title", "Price", "Availability", "Rating"]
data = []

def connect_and_get_data(start, end):
  for i in range(start, end + 1):
        url = f"https://books.toscrape.com/catalogue/page-{i}.html"
        response = requests.get(url)

        if response.status_code == 200:
            soup = bs(response.content, "html.parser")
            books = soup.find_all("article", class_="product_pod")

            if not books:
                print(f"No books found on page {i}")
                continue

            for book in books:
                row_data = []
                title = book.h3.a["title"]
                price = book.find("p", class_="price_color").text.strip()
                availability = book.find("p", class_="instock availability").text.strip()
                rating = book.p["class"][1]

                row_data.extend([title, price, availability, rating])
                data.append(row_data)
        else:
            print(f"Error fetching page {i}")

  return header, data

# %%
#Getting the data from the web page
connect_and_get_data(1, 50)
# Out:
# (['Title', 'Price', 'Availability', 'Rating'],
#  [['A Light in the Attic', '£51.77', 'In stock', 'Three'],
#   ['Tipping the Velvet', '£53.74', 'In stock', 'One'],
#   ['Soumission', '£50.10', 'In stock', 'One'],
#   ['Sharp Objects', '£47.82', 'In stock', 'Four'],
#   ['Sapiens: A Brief History of Humankind', '£54.23', 'In stock', 'Five'],
#   ['The Requiem Red', '£22.65', 'In stock', 'One'],
#   ['The Dirty Little Secrets of Getting Your Dream Job',
#    '£33.34',
#    'In stock',
#    'Four'],
#   ['The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#    '£17.93',
#    'In stock',
#    'Three'],
#   ['The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#    '£22.60',
#    'In stock',
#    'Four'],
#   ['The Black Maria', '£52.15', 'In stock', 'One'],
#   ['Starving Hearts (Triangular Trade Trilogy, #1)',
#    '£13.99',
#    'In stock',
#    'Two'],
#   ["Shakespeare's Sonnets", '£20.66', 'In stock', 'Four'],
#   ['Set Me Free', '£17.46', 'In stock', 'Five'],
#   ["Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#    '£52.29',
#    'In stock',
#    'Five'],
#   ['Rip it Up and Start Again', '£35.02', 'In stock', 'Five'],
#   ['Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#    '£57.25',
#    'In stock',
#    'Three'],
#   ['Olio', '£23.88', 'In stock', 'One'],
#   ['Mesaerion: The Best Science Fiction Stories 1800-1849',
#    '£37.59',
#    'In stock',
#    'One'],
#   ['Libertarianism for Beginners', '£51.33', 'In stock', 'Two'],
#   ["It's Only the Himalayas", '£45.17', 'In stock', 'Two'],
#   ['In Her Wake', '£12.84', 'In stock', 'One'],
#   ['How Music Works', '£37.32', 'In stock', 'Two'],
#   ['Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',
#    '£30.52',
#    'In stock',
#    'Three'],
#   ['Chase Me (Paris Nights #2)', '£25.27', 'In stock', 'Five'],
#   ['Black Dust', '£34.53', 'In stock', 'Five'],
#   ['Birdsong: A Story in Pictures', '£54.64', 'In stock', 'Three'],
#   ["America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",
#    '£22.50',
#    'In stock',
#    'Three'],
#   ['Aladdin and His Wonderful Lamp', '£53.13', 'In stock', 'Three'],
#   ['Worlds Elsewhere: Journeys Around Shakespeare’s Globe',
#    '£40.30',
#    'In stock',
#    'Five'],
#   ['Wall and Piece', '£44.18', 'In stock', 'Four'],
#   ['The Four Agreements: A Practical Guide to Personal Freedom',
#    '£17.66',
#    'In stock',
#    'Five'],
#   ['The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',
#    '£31.05',
#    'In stock',
#    'Three'],
#   ['The Elephant Tree', '£23.82', 'In stock', 'Five'],
#   ['The Bear and the Piano', '£36.89', 'In stock', 'One'],
#   ["Sophie's World", '£15.94', 'In stock', 'Five'],
#   ['Penny Maybe', '£33.29', 'In stock', 'Three'],
#   ['Maude (1883-1993):She Grew Up with the country',
#    '£18.02',
#    'In stock',
#    'Two'],
#   ['In a Dark, Dark Wood', '£19.63', 'In stock', 'One'],
#   ['Behind Closed Doors', '£52.22', 'In stock', 'Four'],
#   ["You can't bury them all: Poems", '£33.63', 'In stock', 'Two'],
#   ['Slow States of Collapse: Poems', '£57.31', 'In stock', 'Three'],
#   ['Reasons to Stay Alive', '£26.41', 'In stock', 'Two'],
#   ['Private Paris (Private #10)', '£47.61', 'In stock', 'Five'],
#   ['#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#    '£23.11',
#    'In stock',
#    'Five'],
#   ['Without Borders (Wanderlove #1)', '£45.07', 'In stock', 'Two'],
#   ['When We Collided', '£31.77', 'In stock', 'One'],
#   ['We Love You, Charlie Freeman', '£50.27', 'In stock', 'Five'],
#   ['Untitled Collection: Sabbath Poems 2014', '£14.27', 'In stock', 'Four'],
#   ['Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#    '£44.18',
#    'In stock',
#    'Four'],
#   ['Unicorn Tracks', '£18.78', 'In stock', 'Three'],
#   ['Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',
#    '£25.52',
#    'In stock',
#    'One'],
#   ['Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#    '£16.28',
#    'In stock',
#    'One'],
#   ['Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',
#    '£31.12',
#    'In stock',
#    'Three'],
#   ['This One Summer', '£19.49', 'In stock', 'Four'],
#   ['Thirst', '£17.27', 'In stock', 'Five'],
#   ['The Torch Is Passed: A Harding Family Story', '£19.09', 'In stock', 'One'],
#   ['The Secret of Dreadwillow Carse', '£56.13', 'In stock', 'One'],
#   ['The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!',
#    '£56.41',
#    'In stock',
#    'One'],
#   ['The Past Never Ends', '£56.50', 'In stock', 'Four'],
#   ['The Natural History of Us (The Fine Art of Pretending #2)',
#    '£45.22',
#    'In stock',
#    'Three'],
#   ['The Nameless City (The Nameless City #1)', '£38.16', 'In stock', 'Four'],
#   ['The Murder That Never Was (Forensic Instincts #5)',
#    '£54.11',
#    'In stock',
#    'Three'],
#   ["The Most Perfect Thing: Inside (and Outside) a Bird's Egg",
#    '£42.96',
#    'In stock',
#    'Four'],
#   ['The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#    '£23.89',
#    'In stock',
#    'Four'],
#   ['The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#    '£16.77',
#    'In stock',
#    'Three'],
#   ['The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#    '£20.59',
#    'In stock',
#    'Five'],
#   ['The Gutsy Girl: Escapades for Your Life of Epic Adventure',
#    '£37.13',
#    'In stock',
#    'One'],
#   ['The Electric Pencil: Drawings from Inside State Hospital No. 3',
#    '£56.06',
#    'In stock',
#    'One'],
#   ['The Death of Humanity: and the Case for Life',
#    '£58.11',
#    'In stock',
#    'Four'],
#   ['The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',
#    '£49.05',
#    'In stock',
#    'Three'],
#   ['The Art Forger', '£40.76', 'In stock', 'Three'],
#   ['The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#    '£19.73',
#    'In stock',
#    'One'],
#   ["The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#    '£32.24',
#    'In stock',
#    'Five'],
#   ['Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#    '£41.83',
#    'In stock',
#    'Four'],
#   ['Soul Reader', '£39.58', 'In stock', 'Two'],
#   ['Security', '£39.25', 'In stock', 'Two'],
#   ['Saga, Volume 6 (Saga (Collected Editions) #6)',
#    '£25.02',
#    'In stock',
#    'Three'],
#   ['Saga, Volume 5 (Saga (Collected Editions) #5)',
#    '£51.04',
#    'In stock',
#    'Two'],
#   ['Reskilling America: Learning to Labor in the Twenty-First Century',
#    '£19.83',
#    'In stock',
#    'Two'],
#   ['Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)',
#    '£50.40',
#    'In stock',
#    'Three'],
#   ['Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#    '£13.61',
#    'In stock',
#    'Five'],
#   ['Princess Between Worlds (Wide-Awake Princess #5)',
#    '£13.34',
#    'In stock',
#    'Five'],
#   ['Pop Gun War, Volume 1: Gift', '£18.97', 'In stock', 'One'],
#   ['Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#    '£36.28',
#    'In stock',
#    'Two'],
#   ['Patience', '£10.16', 'In stock', 'Three'],
#   ['Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#    '£15.44',
#    'In stock',
#    'Four'],
#   ['orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#    '£48.41',
#    'In stock',
#    'One'],
#   ['Online Marketing for Busy Authors: A Step-By-Step Guide',
#    '£46.35',
#    'In stock',
#    'One'],
#   ['On a Midnight Clear', '£14.07', 'In stock', 'Three'],
#   ['Obsidian (Lux #1)', '£14.86', 'In stock', 'Two'],
#   ['My Paris Kitchen: Recipes and Stories', '£33.37', 'In stock', 'Two'],
#   ['Masks and Shadows', '£56.40', 'In stock', 'Two'],
#   ['Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#    '£14.02',
#    'In stock',
#    'Four'],
#   ['Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#    '£46.91',
#    'In stock',
#    'Two'],
#   ['Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#    '£45.61',
#    'In stock',
#    'Three'],
#   ['Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#    '£19.92',
#    'In stock',
#    'Two'],
#   ['Layered: Baking, Building, and Styling Spectacular Cakes',
#    '£40.11',
#    'In stock',
#    'One'],
#   ['Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)',
#    '£53.90',
#    'In stock',
#    'Two'],
#   ['Join', '£35.67', 'In stock', 'Five'],
#   ['In the Country We Love: My Family Divided', '£22.00', 'In stock', 'Four'],
#   ['Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine',
#    '£57.36',
#    'In stock',
#    'Five'],
#   ['I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#    '£29.17',
#    'In stock',
#    'Two'],
#   ['I am a Hero Omnibus Volume 1', '£54.63', 'In stock', 'Three'],
#   ['How to Be Miserable: 40 Strategies You Already Use',
#    '£46.03',
#    'In stock',
#    'One'],
#   ['Her Backup Boyfriend (The Sorensen Family #1)',
#    '£33.97',
#    'In stock',
#    'One'],
#   ['Giant Days, Vol. 2 (Giant Days #5-8)', '£22.11', 'In stock', 'Two'],
#   ['Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',
#    '£29.69',
#    'In stock',
#    'Three'],
#   ['First and First (Five Boroughs #3)', '£15.97', 'In stock', 'Four'],
#   ['Fifty Shades Darker (Fifty Shades #2)', '£21.96', 'In stock', 'One'],
#   ['Everydata: The Misinformation Hidden in the Little Data You Consume Every Day',
#    '£54.35',
#    'In stock',
#    'Two'],
#   ["Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master",
#    '£37.97',
#    'In stock',
#    'Two'],
#   ['Danganronpa Volume 1', '£51.99', 'In stock', 'Four'],
#   ['Crown of Midnight (Throne of Glass #2)', '£43.29', 'In stock', 'Three'],
#   ['Codename Baboushka, Volume 1: The Conclave of Death',
#    '£36.72',
#    'In stock',
#    'Four'],
#   ['Camp Midnight', '£17.08', 'In stock', 'Four'],
#   ['Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
#    '£29.14',
#    'In stock',
#    'Five'],
#   ['Burning', '£28.81', 'In stock', 'Three'],
#   ['Bossypants', '£49.46', 'In stock', 'Two'],
#   ['Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#    '£37.92',
#    'In stock',
#    'Two'],
#   ['Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)',
#    '£28.09',
#    'In stock',
#    'Two'],
#   ['Algorithms to Live By: The Computer Science of Human Decisions',
#    '£30.81',
#    'In stock',
#    'One'],
#   ['A World of Flavor: Your Gluten Free Passport',
#    '£42.95',
#    'In stock',
#    'One'],
#   ['A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations',
#    '£56.76',
#    'In stock',
#    'Five'],
#   ['A Murder in Time', '£16.64', 'In stock', 'One'],
#   ['A Flight of Arrows (The Pathfinders #2)', '£55.53', 'In stock', 'Five'],
#   ['A Fierce and Subtle Poison', '£28.13', 'In stock', 'Four'],
#   ['A Court of Thorns and Roses (A Court of Thorns and Roses #1)',
#    '£52.37',
#    'In stock',
#    'One'],
#   ['(Un)Qualified: How God Uses Broken People to Do Big Things',
#    '£54.00',
#    'In stock',
#    'Five'],
#   ['You Are What You Love: The Spiritual Power of Habit',
#    '£21.87',
#    'In stock',
#    'Four'],
#   ["William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",
#    '£43.30',
#    'In stock',
#    'Four'],
#   ['Tuesday Nights in 1980', '£21.04', 'In stock', 'Two'],
#   ['Tracing Numbers on a Train', '£41.60', 'In stock', 'Three'],
#   ['Throne of Glass (Throne of Glass #1)', '£35.07', 'In stock', 'Three'],
#   ['Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History',
#    '£59.64',
#    'In stock',
#    'One'],
#   ['Thirteen Reasons Why', '£52.72', 'In stock', 'One'],
#   ['The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”',
#    '£58.08',
#    'In stock',
#    'Four'],
#   ['The Wedding Dress', '£24.12', 'In stock', 'One'],
#   ['The Vacationers', '£42.15', 'In stock', 'Four'],
#   ['The Third Wave: An Entrepreneur’s Vision of the Future',
#    '£12.61',
#    'In stock',
#    'Five'],
#   ['The Stranger', '£17.44', 'In stock', 'Four'],
#   ['The Shadow Hero (The Shadow Hero)', '£33.14', 'In stock', 'One'],
#   ['The Secret (The Secret #1)', '£27.37', 'In stock', 'Four'],
#   ['The Regional Office Is Under Attack!', '£51.36', 'In stock', 'Five'],
#   ['The Psychopath Test: A Journey Through the Madness Industry',
#    '£36.00',
#    'In stock',
#    'Two'],
#   ['The Project', '£10.65', 'In stock', 'One'],
#   ['The Power of Now: A Guide to Spiritual Enlightenment',
#    '£43.54',
#    'In stock',
#    'Two'],
#   ["The Omnivore's Dilemma: A Natural History of Four Meals",
#    '£38.21',
#    'In stock',
#    'Two'],
#   ['The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#    '£37.34',
#    'In stock',
#    'Five'],
#   ['The Murder of Roger Ackroyd (Hercule Poirot #4)',
#    '£44.10',
#    'In stock',
#    'Four'],
#   ['The Mistake (Off-Campus #2)', '£43.29', 'In stock', 'Three'],
#   ["The Matchmaker's Playbook (Wingmen Inc. #1)", '£55.85', 'In stock', 'One'],
#   ['The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking',
#    '£37.60',
#    'In stock',
#    'Two'],
#   ['The Long Shadow of Small Ghosts: Murder and Memory in an American City',
#    '£10.97',
#    'In stock',
#    'One'],
#   ['The Kite Runner', '£41.82', 'In stock', 'Four'],
#   ['The House by the Lake', '£36.95', 'In stock', 'One'],
#   ['The Glittering Court (The Glittering Court #1)',
#    '£44.28',
#    'In stock',
#    'One'],
#   ['The Girl on the Train', '£55.02', 'In stock', 'Two'],
#   ['The Genius of Birds', '£17.24', 'In stock', 'One'],
#   ['The Emerald Mystery', '£23.15', 'In stock', 'Two'],
#   ['The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',
#    '£41.25',
#    'In stock',
#    'One'],
#   ["The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",
#    '£32.00',
#    'In stock',
#    'Three'],
#   ["The Artist's Way: A Spiritual Path to Higher Creativity",
#    '£38.49',
#    'In stock',
#    'Five'],
#   ['The Art of War', '£33.34', 'In stock', 'Five'],
#   ['The Argonauts', '£10.93', 'In stock', 'Two'],
#   ['The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',
#    '£27.55',
#    'In stock',
#    'Three'],
#   ['Suddenly in Love (Lake Haven #1)', '£55.99', 'In stock', 'Two'],
#   ['Something More Than This', '£16.24', 'In stock', 'Four'],
#   ['Soft Apocalypse', '£26.12', 'In stock', 'Two'],
#   ["So You've Been Publicly Shamed", '£12.23', 'In stock', 'Two'],
#   ['Shoe Dog: A Memoir by the Creator of NIKE', '£23.99', 'In stock', 'Two'],
#   ['Shobu Samurai, Project Aryoku (#3)', '£29.06', 'In stock', 'Three'],
#   ['Secrets and Lace (Fatal Hearts #1)', '£20.27', 'In stock', 'One'],
#   ['Scarlett Epstein Hates It Here', '£43.55', 'In stock', 'Five'],
#   ['Romero and Juliet: A Tragic Tale of Love and Zombies',
#    '£36.94',
#    'In stock',
#    'One'],
#   ['Redeeming Love', '£20.47', 'In stock', 'Five'],
#   ['Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form',
#    '£41.06',
#    'In stock',
#    'One'],
#   ['Poems That Make Grown Women Cry', '£14.19', 'In stock', 'Four'],
#   ['Nightingale, Sing', '£38.28', 'In stock', 'One'],
#   ['Night Sky with Exit Wounds', '£41.05', 'In stock', 'One'],
#   ['Mrs. Houdini', '£30.25', 'In stock', 'Five'],
#   ['Modern Romance', '£28.26', 'In stock', 'Five'],
#   ['Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)',
#    '£10.76',
#    'In stock',
#    'One'],
#   ['Louisa: The Extraordinary Life of Mrs. Adams',
#    '£16.85',
#    'In stock',
#    'Two'],
#   ['Little Red', '£13.47', 'In stock', 'Three'],
#   ['Library of Souls (Miss Peregrine’s Peculiar Children #3)',
#    '£48.56',
#    'In stock',
#    'Five'],
#   ['Large Print Heart of the Pride', '£19.15', 'In stock', 'Two'],
#   ['I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#    '£57.36',
#    'In stock',
#    'Four'],
#   ['Hollow City (Miss Peregrine’s Peculiar Children #2)',
#    '£42.98',
#    'In stock',
#    'One'],
#   ['Grumbles', '£22.16', 'In stock', 'Two'],
#   ['Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond',
#    '£49.43',
#    'In stock',
#    'Four'],
#   ['Frostbite (Vampire Academy #2)', '£29.99', 'In stock', 'Five'],
#   ['Follow You Home', '£21.36', 'In stock', 'One'],
#   ['First Steps for New Christians (Print Edition)',
#    '£29.00',
#    'In stock',
#    'One'],
#   ['Finders Keepers (Bill Hodges Trilogy #2)', '£53.53', 'In stock', 'Five'],
#   ['Fables, Vol. 1: Legends in Exile (Fables #1)',
#    '£41.62',
#    'In stock',
#    'Four'],
#   ['Eureka Trivia 6.0', '£54.59', 'In stock', 'Four'],
#   ['Drive: The Surprising Truth About What Motivates Us',
#    '£34.95',
#    'In stock',
#    'Four'],
#   ['Done Rubbed Out (Reightman & Bailey #1)', '£37.72', 'In stock', 'Five'],
#   ['Doing It Over (Most Likely To #1)', '£35.61', 'In stock', 'Three'],
#   ['Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',
#    '£42.16',
#    'In stock',
#    'Three'],
#   ['Dark Notes', '£19.19', 'In stock', 'Five'],
#   ['Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#    '£19.43',
#    'In stock',
#    'Three'],
#   ['Close to You', '£49.46', 'In stock', 'Four'],
#   ['Chasing Heaven: What Dying Taught Me About Living',
#    '£37.80',
#    'In stock',
#    'Two'],
#   ['Big Magic: Creative Living Beyond Fear', '£30.80', 'In stock', 'Three'],
#   ['Becoming Wise: An Inquiry into the Mystery and Art of Living',
#    '£27.43',
#    'In stock',
#    'Two'],
#   ['Beauty Restored (Riley Family Legacy Novellas #3)',
#    '£11.11',
#    'In stock',
#    'Two'],
#   ['Batman: The Long Halloween (Batman)', '£36.50', 'In stock', 'Two'],
#   ['Batman: The Dark Knight Returns (Batman)', '£15.38', 'In stock', 'Five'],
#   ["Ayumi's Violin", '£15.48', 'In stock', 'Two'],
#   ['Anonymous', '£46.82', 'In stock', 'Four'],
#   ['Amy Meets the Saints and Sages', '£18.46', 'In stock', 'Three'],
#   ['Amid the Chaos', '£36.58', 'In stock', 'One'],
#   ['Amatus', '£50.54', 'In stock', 'Five'],
#   ['Agnostic: A Spirited Manifesto', '£12.51', 'In stock', 'Five'],
#   ['Zealot: The Life and Times of Jesus of Nazareth',
#    '£24.70',
#    'In stock',
#    'Three'],
#   ['You (You #1)', '£43.61', 'In stock', 'Five'],
#   ['Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#    '£37.34',
#    'In stock',
#    'Four'],
#   ['Wild Swans', '£14.36', 'In stock', 'Two'],
#   ['Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#    '£52.65',
#    'In stock',
#    'Four'],
#   ['Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#    '£38.20',
#    'In stock',
#    'Four'],
#   ["What's It Like in Space?: Stories from Astronauts Who've Been There",
#    '£19.60',
#    'In stock',
#    'Two'],
#   ['We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)',
#    '£53.90',
#    'In stock',
#    'One'],
#   ["Walt Disney's Alice in Wonderland", '£12.96', 'In stock', 'Five'],
#   ['V for Vendetta (V for Vendetta Complete)', '£37.10', 'In stock', 'Four'],
#   ['Until Friday Night (The Field Party #1)', '£46.31', 'In stock', 'Two'],
#   ['Unbroken: A World War II Story of Survival, Resilience, and Redemption',
#    '£45.95',
#    'In stock',
#    'Two'],
#   ['Twenty Yawns', '£22.08', 'In stock', 'Two'],
#   ['Through the Woods', '£25.38', 'In stock', 'Two'],
#   ['This Is Where It Ends', '£27.12', 'In stock', 'Two'],
#   ['The Year of Magical Thinking', '£43.04', 'In stock', 'Two'],
#   ['The Wright Brothers', '£56.80', 'In stock', 'Four'],
#   ["The White Queen (The Cousins' War #1)", '£25.91', 'In stock', 'Five'],
#   ["The Wedding Pact (The O'Malleys #2)", '£32.61', 'In stock', 'Three'],
#   ['The Time Keeper', '£27.88', 'In stock', 'Five'],
#   ['The Testament of Mary', '£52.67', 'In stock', 'Four'],
#   ['The Star-Touched Queen', '£46.02', 'In stock', 'Five'],
#   ['The Songs of the Gods', '£44.48', 'In stock', 'Five'],
#   ['The Song of Achilles', '£37.40', 'In stock', 'Five'],
#   ['The Rosie Project (Don Tillman #1)', '£54.04', 'In stock', 'One'],
#   ['The Power of Habit: Why We Do What We Do in Life and Business',
#    '£16.88',
#    'In stock',
#    'Three'],
#   ['The Marriage of Opposites', '£28.08', 'In stock', 'Four'],
#   ['The Lucifer Effect: Understanding How Good People Turn Evil',
#    '£10.40',
#    'In stock',
#    'One'],
#   ['The Long Haul (Diary of a Wimpy Kid #9)', '£44.07', 'In stock', 'One'],
#   ['The Loney', '£23.40', 'In stock', 'One'],
#   ['The Literature Book (Big Ideas Simply Explained)',
#    '£17.43',
#    'In stock',
#    'Three'],
#   ['The Last Mile (Amos Decker #2)', '£54.21', 'In stock', 'Two'],
#   ['The Immortal Life of Henrietta Lacks', '£40.67', 'In stock', 'Two'],
#   ['The Hidden Oracle (The Trials of Apollo #1)', '£52.26', 'In stock', 'Two'],
#   ['The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth',
#    '£28.77',
#    'In stock',
#    'Three'],
#   ['The Guilty (Will Robie #4)', '£13.82', 'In stock', 'Two'],
#   ['The First Hostage (J.B. Collins #2)', '£25.85', 'In stock', 'Three'],
#   ['The Dovekeepers', '£48.78', 'In stock', 'One'],
#   ['The Darkest Lie', '£35.35', 'In stock', 'Five'],
#   ['The Bane Chronicles (The Bane Chronicles #1-11)',
#    '£44.73',
#    'In stock',
#    'Four'],
#   ['The Bad-Ass Librarians of Timbuktu: And Their Race to Save the World’s Most Precious Manuscripts',
#    '£15.77',
#    'In stock',
#    'One'],
#   ['The 14th Colony (Cotton Malone #11)', '£39.24', 'In stock', 'One'],
#   ['That Darkness (Gardiner and Renner #1)', '£13.92', 'In stock', 'One'],
#   ['Tastes Like Fear (DI Marnie Rome #3)', '£10.69', 'In stock', 'One'],
#   ['Take Me with You', '£45.21', 'In stock', 'Three'],
#   ['Swell: A Year of Waves', '£45.58', 'In stock', 'One'],
#   ['Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)',
#    '£11.89',
#    'In stock',
#    'Five'],
#   ['Still Life with Bread Crumbs', '£26.41', 'In stock', 'Three'],
#   ['Steve Jobs', '£39.50', 'In stock', 'Five'],
#   ['Sorting the Beef from the Bull: The Science of Food Fraud Forensics',
#    '£44.74',
#    'In stock',
#    'Four'],
#   ['Someone Like You (The Harrisons #2)', '£52.79', 'In stock', 'Five'],
#   ['So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',
#    '£35.43',
#    'In stock',
#    'Four'],
#   ['Shtum', '£55.84', 'In stock', 'Four'],
#   ['See America: A Celebration of Our National Parks & Treasured Sites',
#    '£48.87',
#    'In stock',
#    'Three'],
#   ['salt.', '£46.78', 'In stock', 'Four'],
#   ['Robin War', '£47.82', 'In stock', 'Three'],
#   ['Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)',
#    '£25.48',
#    'In stock',
#    'Two'],
#   ['Rain Fish', '£23.57', 'In stock', 'Three'],
#   ['Quarter Life Poetry: Poems for the Young, Broke and Hangry',
#    '£50.89',
#    'In stock',
#    'Five'],
#   ['Pet Sematary', '£10.56', 'In stock', 'Three'],
#   ['Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress',
#    '£52.15',
#    'In stock',
#    'Three'],
#   ['Once Was a Time', '£18.28', 'In stock', 'Two'],
#   ['Old School (Diary of a Wimpy Kid #10)', '£11.83', 'In stock', 'Five'],
#   ['No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon',
#    '£21.95',
#    'In stock',
#    'Two'],
#   ['Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)',
#    '£38.39',
#    'In stock',
#    'Two'],
#   ['My Name Is Lucy Barton', '£41.56', 'In stock', 'One'],
#   ['My Mrs. Brown', '£24.48', 'In stock', 'Three'],
#   ['My Kind of Crazy', '£40.36', 'In stock', 'One'],
#   ['Mr. Mercedes (Bill Hodges Trilogy #1)', '£28.90', 'In stock', 'One'],
#   ['More Than Music (Chasing the Dream #1)', '£37.61', 'In stock', 'Two'],
#   ['Made to Stick: Why Some Ideas Survive and Others Die',
#    '£38.85',
#    'In stock',
#    'Five'],
#   ['Luis Paints the World', '£53.95', 'In stock', 'Three'],
#   ['Luckiest Girl Alive', '£49.83', 'In stock', 'Three'],
#   ['Lowriders to the Center of the Earth (Lowriders in Space #2)',
#    '£51.51',
#    'In stock',
#    'Two'],
#   ['Love Is a Mix Tape (Music #1)', '£18.03', 'In stock', 'One'],
#   ['Looking for Lovely: Collecting the Moments that Matter',
#    '£29.14',
#    'In stock',
#    'Five'],
#   ['Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments',
#    '£46.91',
#    'In stock',
#    'Four'],
#   ['Let It Out: A Journey Through Journaling', '£26.79', 'In stock', 'Five'],
#   ['Lady Midnight (The Dark Artifices #1)', '£16.28', 'In stock', 'Five'],
#   ["It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes",
#    '£19.55',
#    'In stock',
#    'One'],
#   ['Island of Dragons (Unwanteds #7)', '£29.65', 'In stock', 'One'],
#   ["I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",
#    '£25.98',
#    'In stock',
#    'Four'],
#   ['I Am Pilgrim (Pilgrim #1)', '£10.60', 'In stock', 'Four'],
#   ['Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#    '£14.75',
#    'In stock',
#    'Five'],
#   ['Hush, Hush (Hush, Hush #1)', '£47.02', 'In stock', 'Three'],
#   ['Hold Your Breath (Search and Rescue #1)', '£28.82', 'In stock', 'One'],
#   ['Hamilton: The Revolution', '£58.79', 'In stock', 'Three'],
#   ['Greek Mythic History', '£10.23', 'In stock', 'Five'],
#   ['God: The Most Unpleasant Character in All Fiction',
#    '£30.03',
#    'In stock',
#    'Five'],
#   ['Glory over Everything: Beyond The Kitchen House',
#    '£45.84',
#    'In stock',
#    'Three'],
#   ['Feathers: Displays of Brilliant Plumage', '£49.05', 'In stock', 'Three'],
#   ['Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#    '£15.06',
#    'In stock',
#    'Four'],
#   ['Every Last Word', '£46.47', 'In stock', 'Three'],
#   ['Eligible (The Austen Project #4)', '£27.09', 'In stock', 'Three'],
#   ['El Deafo', '£57.62', 'In stock', 'Five'],
#   ['Eight Hundred Grapes', '£14.39', 'In stock', 'Four'],
#   ['Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life',
#    '£51.75',
#    'In stock',
#    'Five'],
#   ['Eat Fat, Get Thin', '£54.07', 'In stock', 'Two'],
#   ["Don't Get Caught", '£55.35', 'In stock', 'One'],
#   ['Doctor Sleep (The Shining #2)', '£40.12', 'In stock', 'Two'],
#   ['Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)',
#    '£37.51',
#    'In stock',
#    'Five'],
#   ['Dear Mr. Knightley', '£11.21', 'In stock', 'Five'],
#   ['Daily Fantasy Sports', '£36.58', 'In stock', 'One'],
#   ['Crazy Love: Overwhelmed by a Relentless God', '£47.72', 'In stock', 'Two'],
#   ['Cometh the Hour (The Clifton Chronicles #6)',
#    '£25.01',
#    'In stock',
#    'Three'],
#   ['Code Name Verity (Code Name Verity #1)', '£22.13', 'In stock', 'Four'],
#   ['Clockwork Angel (The Infernal Devices #1)', '£44.14', 'In stock', 'One'],
#   ['City of Glass (The Mortal Instruments #3)', '£56.02', 'In stock', 'Four'],
#   ['City of Fallen Angels (The Mortal Instruments #4)',
#    '£11.23',
#    'In stock',
#    'Four'],
#   ['City of Bones (The Mortal Instruments #1)', '£43.28', 'In stock', 'One'],
#   ['City of Ashes (The Mortal Instruments #2)', '£47.27', 'In stock', 'One'],
#   ['Cell', '£20.29', 'In stock', 'Four'],
#   ['Catching Jordan (Hundred Oaks)', '£50.83', 'In stock', 'Three'],
#   ['Carry On, Warrior: Thoughts on Life Unarmed',
#    '£31.85',
#    'In stock',
#    'Three'],
#   ['Carrie', '£46.23', 'In stock', 'Two'],
#   ['Buying In: The Secret Dialogue Between What We Buy and Who We Are',
#    '£37.80',
#    'In stock',
#    'Four'],
#   ['Brain on Fire: My Month of Madness', '£49.32', 'In stock', 'Five'],
#   ['Batman: Europa', '£32.01', 'In stock', 'Two'],
#   ['Barefoot Contessa Back to Basics', '£28.01', 'In stock', 'One'],
#   ["Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#    '£50.62',
#    'In stock',
#    'Five'],
#   ['Balloon Animals', '£17.03', 'In stock', 'Three'],
#   ['Art Ops Vol. 1', '£48.80', 'In stock', 'Three'],
#   ['Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',
#    '£58.14',
#    'In stock',
#    'Four'],
#   ['Angels Walking (Angels Walking #1)', '£34.20', 'In stock', 'Two'],
#   ['Angels & Demons (Robert Langdon #1)', '£51.48', 'In stock', 'Three'],
#   ['All the Light We Cannot See', '£29.87', 'In stock', 'Five'],
#   ['Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection',
#    '£10.90',
#    'In stock',
#    'Two'],
#   ['Abstract City', '£56.37', 'In stock', 'Five'],
#   ['A Time of Torment (Charlie Parker #14)', '£48.35', 'In stock', 'Five'],
#   ['A Study in Scarlet (Sherlock Holmes #1)', '£16.73', 'In stock', 'Two'],
#   ['A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer',
#    '£56.48',
#    'In stock',
#    'Two'],
#   ["A People's History of the United States", '£40.79', 'In stock', 'Two'],
#   ['A Man Called Ove', '£39.72', 'In stock', 'One'],
#   ['A Distant Mirror: The Calamitous 14th Century',
#    '£14.58',
#    'In stock',
#    'Three'],
#   ['A Brush of Wings (Angels Walking #3)', '£55.51', 'In stock', 'One'],
#   ['1491: New Revelations of the Americas Before Columbus',
#    '£21.80',
#    'In stock',
#    'Three'],
#   ['The Three Searches, Meaning, and the Story',
#    '£13.33',
#    'In stock',
#    'Three'],
#   ['Searching for Meaning in Gailana', '£38.73', 'In stock', 'One'],
#   ['Rook', '£37.86', 'In stock', 'Four'],
#   ['My Kitchen Year: 136 Recipes That Saved My Life',
#    '£11.53',
#    'In stock',
#    'Two'],
#   ['13 Hours: The Inside Account of What Really Happened In Benghazi',
#    '£27.06',
#    'In stock',
#    'One'],
#   ["Will You Won't You Want Me?", '£13.86', 'In stock', 'Three'],
#   ['Tipping Point for Planet Earth: How Close Are We to the Edge?',
#    '£37.55',
#    'In stock',
#    'One'],
#   ['The Star-Touched Queen', '£32.30', 'In stock', 'Five'],
#   ['The Silent Sister (Riley MacPherson #1)', '£46.29', 'In stock', 'Five'],
#   ['The Midnight Watch: A Novel of the Titanic and the Californian',
#    '£26.20',
#    'In stock',
#    'One'],
#   ['The Lonely City: Adventures in the Art of Being Alone',
#    '£33.26',
#    'In stock',
#    'Two'],
#   ['The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',
#    '£59.15',
#    'In stock',
#    'Four'],
#   ['The Golden Condom: And Other Essays on Love Lost and Found',
#    '£39.43',
#    'In stock',
#    'One'],
#   ['The Epidemic (The Program 0.6)', '£14.44', 'In stock', 'Five'],
#   ['The Dinner Party', '£56.54', 'In stock', 'Two'],
#   ['The Diary of a Young Girl', '£59.90', 'In stock', 'Three'],
#   ['The Children', '£11.88', 'In stock', 'Three'],
#   ['Stars Above (The Lunar Chronicles #4.5)', '£48.05', 'In stock', 'Two'],
#   ['Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',
#    '£21.21',
#    'In stock',
#    'Three'],
#   ['Raspberry Pi Electronics Projects for the Evil Genius',
#    '£49.67',
#    'In stock',
#    'Four'],
#   ['Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#    '£43.14',
#    'In stock',
#    'One'],
#   ['Psycho: Sanitarium (Psycho #1.5)', '£36.97', 'In stock', 'Five'],
#   ['Poisonous (Max Revere Novels #3)', '£26.80', 'In stock', 'Three'],
#   ['One with You (Crossfire #5)', '£15.71', 'In stock', 'Four'],
#   ['No Love Allowed (Dodge Cove #1)', '£54.65', 'In stock', 'Four'],
#   ['Murder at the 42nd Street Library (Raymond Ambler #1)',
#    '£54.36',
#    'In stock',
#    'Four'],
#   ['Most Wanted', '£35.28', 'In stock', 'Three'],
#   ['Love, Lies and Spies', '£20.55', 'In stock', 'Two'],
#   ['How to Speak Golf: An Illustrated Guide to Links Lingo',
#    '£58.32',
#    'In stock',
#    'Five'],
#   ['Hide Away (Eve Duncan #20)', '£11.84', 'In stock', 'One'],
#   ['Furiously Happy: A Funny Book About Horrible Things',
#    '£41.46',
#    'In stock',
#    'Four'],
#   ['Everyday Italian: 125 Simple and Delicious Recipes',
#    '£20.10',
#    'In stock',
#    'Five'],
#   ["Equal Is Unfair: America's Misguided Fight Against Income Inequality",
#    '£56.86',
#    'In stock',
#    'One'],
#   ['Eleanor & Park', '£56.51', 'In stock', 'Five'],
#   ['Dirty (Dive Bar #1)', '£40.83', 'In stock', 'Four'],
#   ['Can You Keep a Secret? (Fear Street Relaunch #4)',
#    '£48.64',
#    'In stock',
#    'One'],
#   ['Boar Island (Anna Pigeon #19)', '£59.48', 'In stock', 'Three'],
#   ['A Paris Apartment', '£39.01', 'In stock', 'Four'],
#   ['A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',
#    '£38.77',
#    'In stock',
#    'One'],
#   ['Troublemaker: Surviving Hollywood and Scientology',
#    '£48.39',
#    'In stock',
#    'Two'],
#   ['The Widow', '£27.26', 'In stock', 'Two'],
#   ['The Sleep Revolution: Transforming Your Life, One Night at a Time',
#    '£11.68',
#    'In stock',
#    'Four'],
#   ['The Improbability of Love', '£59.45', 'In stock', 'One'],
#   ['The Art of Startup Fundraising', '£21.00', 'In stock', 'Three'],
#   ['Take Me Home Tonight (Rock Star Romance #3)',
#    '£53.98',
#    'In stock',
#    'Three'],
#   ['Sleeping Giants (Themis Files #1)', '£48.74', 'In stock', 'One'],
#   ['Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#    '£21.15',
#    'In stock',
#    'Two'],
#   ['Playing with Fire', '£13.71', 'In stock', 'Three'],
#   ['Off the Hook (Fishing for Trouble #1)', '£47.67', 'In stock', 'Three'],
#   ['Mothering Sunday', '£13.34', 'In stock', 'Two'],
#   ['Mother, Can You Not?', '£16.89', 'In stock', 'Five'],
#   ['M Train', '£27.18', 'In stock', 'One'],
#   ['Lilac Girls', '£17.28', 'In stock', 'Two'],
#   ['Lies and Other Acts of Love', '£45.14', 'In stock', 'One'],
#   ['Lab Girl', '£40.85', 'In stock', 'One'],
#   ['Keep Me Posted', '£20.46', 'In stock', 'Four'],
#   ["It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle",
#    '£56.27',
#    'In stock',
#    'Three'],
#   ['Grey (Fifty Shades #4)', '£48.49', 'In stock', 'Four'],
#   ['Exit, Pursued by a Bear', '£51.34', 'In stock', 'Four'],
#   ['Daredevils', '£16.34', 'In stock', 'Three'],
#   ['Cravings: Recipes for What You Want to Eat',
#    '£20.50',
#    'In stock',
#    'Three'],
#   ['Born for This: How to Find the Work You Were Meant to Do',
#    '£21.59',
#    'In stock',
#    'Five'],
#   ['Arena', '£21.36', 'In stock', 'Four'],
#   ['Adultery', '£20.88', 'In stock', 'Five'],
#   ["A Mother's Reckoning: Living in the Aftermath of Tragedy",
#    '£19.53',
#    'In stock',
#    'Three'],
#   ["A Gentleman's Position (Society of Gentlemen #3)",
#    '£14.75',
#    'In stock',
#    'Five'],
#   ['11/22/63', '£48.48', 'In stock', 'Three'],
#   ['10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works',
#    '£24.57',
#    'In stock',
#    'Two'],
#   ['10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!',
#    '£49.71',
#    'In stock',
#    'Five'],
#   ['Without Shame', '£48.27', 'In stock', 'Five'],
#   ['Watchmen', '£58.05', 'In stock', 'Four'],
#   ['Unlimited Intuition Now', '£58.87', 'In stock', 'Four'],
#   ['Underlying Notes', '£11.82', 'In stock', 'Two'],
#   ['The Shack', '£28.03', 'In stock', 'One'],
#   ['The New Brand You: Your New Image Makes the Sale for You',
#    '£44.05',
#    'In stock',
#    'Five'],
#   ['The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#    '£12.34',
#    'In stock',
#    'Four'],
#   ['The Flowers Lied', '£16.68', 'In stock', 'Two'],
#   ['The Fabric of the Cosmos: Space, Time, and the Texture of Reality',
#    '£55.91',
#    'In stock',
#    'One'],
#   ['The Book of Mormon', '£24.57', 'In stock', 'Three'],
#   ['The Art and Science of Low Carbohydrate Living',
#    '£52.98',
#    'In stock',
#    'Five'],
#   ['The Alien Club', '£54.40', 'In stock', 'One'],
#   ['Suzie Snowflake: One beautiful flake (a self-esteem story)',
#    '£54.81',
#    'In stock',
#    'Five'],
#   ['Nap-a-Roo', '£25.08', 'In stock', 'One'],
#   ['NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#    '£10.41',
#    'In stock',
#    'Four'],
#   ['Modern Day Fables', '£47.44', 'In stock', 'Two'],
#   ["If I Gave You God's Phone Number....: Searching for Spirituality in America",
#    '£20.91',
#    'In stock',
#    'One'],
#   ['Fruits Basket, Vol. 9 (Fruits Basket #9)', '£33.95', 'In stock', 'Four'],
#   ['Dress Your Family in Corduroy and Denim', '£43.68', 'In stock', 'Three'],
#   ["Don't Forget Steven", '£33.23', 'In stock', 'One'],
#   ["Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster",
#    '£35.92',
#    'In stock',
#    'Two'],
#   ['Art and Fear: Observations on the Perils (and Rewards) of Artmaking',
#    '£48.63',
#    'In stock',
#    'Four'],
#   ['A Shard of Ice (The Black Symphony Saga #1)',
#    '£56.63',
#    'In stock',
#    'Three'],
#   ["A Hero's Curse (The Unseen Chronicles #1)", '£50.49', 'In stock', 'Three'],
#   ['23 Degrees South: A Tropical Tale of Changing Whether...',
#    '£35.79',
#    'In stock',
#    'Two'],
#   ['Zero to One: Notes on Startups, or How to Build the Future',
#    '£34.06',
#    'In stock',
#    'Three'],
#   ['Why Not Me?', '£17.76', 'In stock', 'One'],
#   ['When Breath Becomes Air', '£39.36', 'In stock', 'Two'],
#   ['Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#    '£36.94',
#    'In stock',
#    'Two'],
#   ['The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)',
#    '£43.62',
#    'In stock',
#    'Five'],
#   ['The New Drawing on the Right Side of the Brain',
#    '£43.02',
#    'In stock',
#    'Three'],
#   ["The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",
#    '£28.45',
#    'In stock',
#    'Four'],
#   ['The Martian (The Martian #1)', '£41.39', 'In stock', 'Two'],
#   ['The High Mountains of Portugal', '£51.15', 'In stock', 'One'],
#   ['The Grownup', '£35.88', 'In stock', 'One'],
#   ["The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It",
#    '£36.91',
#    'In stock',
#    'One'],
#   ['South of Sunshine', '£28.93', 'In stock', 'One'],
#   ['Smarter Faster Better: The Secrets of Being Productive in Life and Business',
#    '£38.89',
#    'In stock',
#    'Five'],
#   ['Silence in the Dark (Logan Point #4)', '£58.33', 'In stock', 'Three'],
#   ['Shadows of the Past (Logan Point #1)', '£39.67', 'In stock', 'Five'],
#   ['Roller Girl', '£14.10', 'In stock', 'Five'],
#   ['Rising Strong', '£21.82', 'In stock', 'Three'],
#   ['Proofs of God: Classical Arguments from Tertullian to Barth',
#    '£54.21',
#    'In stock',
#    'One'],
#   ['Please Kill Me: The Uncensored Oral History of Punk',
#    '£31.19',
#    'In stock',
#    'Four'],
#   ['Out of Print: City Lights Spotlight No. 14', '£53.64', 'In stock', 'Five'],
#   ['My Life Next Door (My Life Next Door )', '£36.39', 'In stock', 'Five'],
#   ["Miller's Valley", '£58.54', 'In stock', 'Two'],
#   ["Man's Search for Meaning", '£29.48', 'In stock', 'Three'],
#   ["Love That Boy: What Two Presidents, Eight Road Trips, and My Son Taught Me About a Parent's Expectations",
#    '£25.06',
#    'In stock',
#    'Two'],
#   ['Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want',
#    '£12.55',
#    'In stock',
#    'Three'],
#   ['Les Fleurs du Mal', '£29.04', 'In stock', 'Five'],
#   ['Left Behind (Left Behind #1)', '£40.72', 'In stock', 'Two'],
#   ["Kill 'Em and Leave: Searching for James Brown and the American Soul",
#    '£45.05',
#    'In stock',
#    'Five'],
#   ['Kierkegaard: A Christian Missionary to Christians',
#    '£47.13',
#    'In stock',
#    'One'],
#   ['John Vassos: Industrial Design for Modern Life',
#    '£20.22',
#    'In stock',
#    'Four'],
#   ["I'll Give You the Sun", '£56.48', 'In stock', 'One'],
#   ['I Will Find You', '£44.21', 'In stock', 'One'],
#   ['Hystopia: A Novel', '£21.96', 'In stock', 'Four'],
#   ['Howl and Other Poems', '£40.45', 'In stock', 'Two'],
#   ['History of Beauty', '£10.29', 'In stock', 'Four'],
#   ["Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back",
#    '£52.86',
#    'In stock',
#    'Two'],
#   ['Future Shock (Future Shock #1)', '£55.65', 'In stock', 'Five'],
#   ["Ender's Game (The Ender Quintet #1)", '£43.64', 'In stock', 'One'],
#   ['Diary of a Citizen Scientist: Chasing Tiger Beetles and Other New Ways of Engaging the World',
#    '£28.41',
#    'In stock',
#    'One'],
#   ['Death by Leisure: A Cautionary Tale', '£37.51', 'In stock', 'Four'],
#   ['Brilliant Beacons: A History of the American Lighthouse',
#    '£11.45',
#    'In stock',
#    'Three'],
#   ["Brazen: The Courage to Find the You That's Been Hiding",
#    '£19.22',
#    'In stock',
#    'Two'],
#   ['Between the World and Me', '£56.91', 'In stock', 'Four'],
#   ['Being Mortal: Medicine and What Matters in the End',
#    '£55.06',
#    'In stock',
#    'Four'],
#   ['A Murder Over a Girl: Justice, Gender, Junior High',
#    '£13.20',
#    'In stock',
#    'Three'],
#   ['32 Yolks', '£53.63', 'In stock', 'Two'],
#   ['"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination',
#    '£44.48',
#    'In stock',
#    'Five'],
#   ['You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#    '£12.08',
#    'In stock',
#    'Three'],
#   ['Wildlife of New York: A Five-Borough Coloring Book',
#    '£22.14',
#    'In stock',
#    'Two'],
#   ['What Happened on Beale Street (Secrets of the South Mysteries #2)',
#    '£25.37',
#    'In stock',
#    'Five'],
#   ['Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain',
#    '£46.33',
#    'In stock',
#    'Two'],
#   ['Under the Tuscan Sun', '£37.33', 'In stock', 'Three'],
#   ["Toddlers Are A**holes: It's Not Your Fault", '£25.55', 'In stock', 'One'],
#   ["The Year of Living Biblically: One Man's Humble Quest to Follow the Bible as Literally as Possible",
#    '£34.72',
#    'In stock',
#    'One'],
#   ['The Whale', '£35.96', 'In stock', 'Four'],
#   ['The Story of Art', '£41.14', 'In stock', 'Four'],
#   ['The Origin of Species', '£10.01', 'In stock', 'Four'],
#   ['The Great Gatsby', '£36.05', 'In stock', 'Four'],
#   ['The Good Girl', '£49.03', 'In stock', 'Three'],
#   ['The Glass Castle', '£16.24', 'In stock', 'One'],
#   ["The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist",
#    '£39.55',
#    'In stock',
#    'One'],
#   ['The Drowning Girls', '£35.67', 'In stock', 'Three'],
#   ['The Constant Princess (The Tudor Court #1)',
#    '£16.62',
#    'In stock',
#    'Three'],
#   ['The Bourne Identity (Jason Bourne #1)', '£42.78', 'In stock', 'Four'],
#   ["The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",
#    '£52.30',
#    'In stock',
#    'Five'],
#   ['The Art Book', '£32.34', 'In stock', 'Two'],
#   ['The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change',
#    '£33.17',
#    'In stock',
#    'Four'],
#   ['Team of Rivals: The Political Genius of Abraham Lincoln',
#    '£20.12',
#    'In stock',
#    'Five'],
#   ['Steal Like an Artist: 10 Things Nobody Told You About Being Creative',
#    '£20.90',
#    'In stock',
#    'Two'],
#   ['Sit, Stay, Love', '£20.90', 'In stock', 'Three'],
#   ['Sister Dear', '£40.20', 'In stock', 'Four'],
#   ['Shrunken Treasures: Literary Classics, Short, Sweet, and Silly',
#    '£52.87',
#    'In stock',
#    'Three'],
#   ['Rich Dad, Poor Dad', '£51.74', 'In stock', 'One'],
#   ['Raymie Nightingale', '£34.41', 'In stock', 'Two'],
#   ['Playing from the Heart', '£32.38', 'In stock', 'One'],
#   ['Nightstruck: A Novel', '£50.35', 'In stock', 'Four'],
#   ['Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#    '£11.38',
#    'In stock',
#    'Five'],
#   ['Meternity', '£43.58', 'In stock', 'Three'],
#   ['Memoirs of a Geisha', '£49.67', 'In stock', 'Three'],
#   ['Like Never Before (Walker Family #2)', '£28.77', 'In stock', 'Two'],
#   ['Life of Pi', '£13.22', 'In stock', 'Four'],
#   ['Leave This Song Behind: Teen Poetry at Its Best',
#    '£51.17',
#    'In stock',
#    'Five'],
#   ["King's Folly (The Kinsman Chronicles #1)", '£39.61', 'In stock', 'Five'],
#   ['John Adams', '£57.43', 'In stock', 'Four'],
#   ['How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',
#    '£46.01',
#    'In stock',
#    'Four'],
#   ['How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking',
#    '£28.25',
#    'In stock',
#    'Two'],
#   ['Good in Bed (Cannie Shapiro #1)', '£37.05', 'In stock', 'Five'],
#   ['Fruits Basket, Vol. 7 (Fruits Basket #7)', '£19.57', 'In stock', 'One'],
#   ['For the Love: Fighting for Grace in a World of Impossible Standards',
#    '£45.13',
#    'In stock',
#    'Three'],
#   ['Finding God in the Ruins: How God Redeems Pain',
#    '£46.64',
#    'In stock',
#    'Two'],
#   ['Every Heart a Doorway (Every Heart A Doorway #1)',
#    '£12.16',
#    'In stock',
#    'Five'],
#   ['Delivering the Truth (Quaker Midwife Mystery #1)',
#    '£20.89',
#    'In stock',
#    'Four'],
#   ['Counted With the Stars (Out from Egypt #1)', '£17.97', 'In stock', 'Five'],
#   ['Chronicles, Vol. 1', '£52.60', 'In stock', 'Two'],
#   ['Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality',
#    '£25.77',
#    'In stock',
#    'One'],
#   ['Benjamin Franklin: An American Life', '£48.19', 'In stock', 'Three'],
#   ['At The Existentialist Café: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others',
#    '£29.93',
#    'In stock',
#    'Five'],
#   ['A Summer In Europe', '£44.34', 'In stock', 'Two'],
#   ['A Short History of Nearly Everything', '£52.40', 'In stock', 'Five'],
#   ['A Gathering of Shadows (Shades of Magic #2)',
#    '£44.81',
#    'In stock',
#    'Four'],
#   ['The Sound Of Love', '£57.84', 'In stock', 'Five'],
#   ['The Rise and Fall of the Third Reich: A History of Nazi Germany',
#    '£39.67',
#    'In stock',
#    'Two'],
#   ['The Perks of Being a Wallflower', '£55.02', 'In stock', 'Three'],
#   ['The Mysterious Affair at Styles (Hercule Poirot #1)',
#    '£24.80',
#    'In stock',
#    'Four'],
#   ['The Man Who Mistook His Wife for a Hat and Other Clinical Tales',
#    '£59.45',
#    'In stock',
#    'Four'],
#   ['The Makings of a Fatherless Child', '£31.58', 'In stock', 'Two'],
#   ['The Joy of Cooking', '£43.27', 'In stock', 'Four'],
#   ['The Invention of Wings', '£37.34', 'In stock', 'One'],
#   ['The Hobbit (Middle-Earth Universe)', '£17.80', 'In stock', 'Five'],
#   ['The Great Railway Bazaar', '£30.54', 'In stock', 'One'],
#   ['The Golden Compass (His Dark Materials #1)', '£18.77', 'In stock', 'One'],
#   ['The God Delusion', '£46.85', 'In stock', 'Three'],
#   ['The Girl You Left Behind (The Girl You Left Behind #1)',
#    '£15.79',
#    'In stock',
#    'One'],
#   ['The Fellowship of the Ring (The Lord of the Rings #1)',
#    '£10.27',
#    'In stock',
#    'Two'],
#   ['The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)',
#    '£15.42',
#    'In stock',
#    'Five'],
#   ['The Barefoot Contessa Cookbook', '£59.92', 'In stock', 'Five'],
#   ["Tell the Wolves I'm Home", '£50.96', 'In stock', 'Two'],
#   ['Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman',
#    '£30.60',
#    'In stock',
#    'Three'],
#   ['Pride and Prejudice', '£19.27', 'In stock', 'Four'],
#   ['Musicophilia: Tales of Music and the Brain', '£46.58', 'In stock', 'One'],
#   ['Mere Christianity', '£48.51', 'In stock', 'Three'],
#   ['Me Before You (Me Before You #1)', '£19.02', 'In stock', 'One'],
#   ['In the Woods (Dublin Murder Squad #1)', '£38.38', 'In stock', 'Two'],
#   ['In Cold Blood', '£49.98', 'In stock', 'Four'],
#   ['How to Stop Worrying and Start Living', '£46.49', 'In stock', 'Five'],
#   ['Give It Back', '£18.32', 'In stock', 'Two'],
#   ['Girl, Interrupted', '£42.14', 'In stock', 'Three'],
#   ['Fun Home: A Family Tragicomic', '£56.59', 'In stock', 'Four'],
#   ['Fruits Basket, Vol. 6 (Fruits Basket #6)', '£20.96', 'In stock', 'Four'],
#   ['Deception Point', '£40.32', 'In stock', 'Four'],
#   ['Death Note, Vol. 6: Give-and-Take (Death Note #6)',
#    '£36.39',
#    'In stock',
#    'Three'],
#   ['Catherine the Great: Portrait of a Woman', '£58.55', 'In stock', 'Four'],
#   ['Better Homes and Gardens New Cook Book', '£39.61', 'In stock', 'Three'],
# ...
#   ['Seven Brief Lessons on Physics', '£30.60', 'In stock', 'Four'],
#   ['Scarlet (The Lunar Chronicles #2)', '£14.57', 'In stock', 'Four'],
#   ["Sarah's Key", '£46.29', 'In stock', 'One'],
#   ['Saga, Volume 3 (Saga (Collected Editions) #3)',
#    '£21.57',
#    'In stock',
#    'Five'],
#   ['Running with Scissors', '£12.91', 'In stock', 'Four'],
#   ['Rogue Lawyer (Rogue Lawyer #1)', '£50.11', 'In stock', 'Three'],
#   ['Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars',
#    '£41.67',
#    'In stock',
#    'Four'],
#   ['Rework', '£44.88', 'In stock', 'Two'],
#   ['Reservations for Two', '£11.10', 'In stock', 'Three'],
#   ['Red: The True Story of Red Riding Hood', '£28.54', 'In stock', 'Three'],
#   ['Ready Player One', '£19.07', 'In stock', 'Four'],
#   ["Quiet: The Power of Introverts in a World That Can't Stop Talking",
#    '£43.55',
#    'In stock',
#    'One'],
#   ['Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)',
#    '£43.63',
#    'In stock',
#    'Three'],
#   ['Persepolis: The Story of a Childhood (Persepolis #1-2)',
#    '£39.13',
#    'In stock',
#    'One'],
#   ['Packing for Mars: The Curious Science of Life in the Void',
#    '£56.68',
#    'In stock',
#    'Two'],
#   ['Outliers: The Story of Success', '£14.16', 'In stock', 'One'],
#   ['Original Fake', '£31.45', 'In stock', 'Three'],
#   ['Orange Is the New Black', '£24.61', 'In stock', 'Two'],
#   ['One for the Money (Stephanie Plum #1)', '£32.87', 'In stock', 'Two'],
#   ['Notes from a Small Island (Notes From a Small Island #1)',
#    '£40.17',
#    'In stock',
#    'One'],
#   ['Night (The Night Trilogy #1)', '£13.51', 'In stock', 'One'],
#   ['Neither Here nor There: Travels in Europe', '£38.95', 'In stock', 'Three'],
#   ['Naked', '£31.69', 'In stock', 'Three'],
#   ['Morning Star (Red Rising #3)', '£29.40', 'In stock', 'One'],
#   ['Miracles from Heaven: A Little Girl, Her Journey to Heaven, and Her Amazing Story of Healing',
#    '£57.83',
#    'In stock',
#    'One'],
#   ['Midnight Riot (Peter Grant/ Rivers of London - books #1)',
#    '£55.46',
#    'In stock',
#    'Two'],
#   ['Me Talk Pretty One Day', '£57.60', 'In stock', 'Two'],
#   ['Manuscript Found in Accra', '£34.98', 'In stock', 'Two'],
#   ['Lust & Wonder', '£11.87', 'In stock', 'Two'],
#   ['Lila (Gilead #3)', '£12.47', 'In stock', 'Three'],
#   ["Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3)",
#    '£33.26',
#    'In stock',
#    'Two'],
#   ['Life Without a Recipe', '£59.04', 'In stock', 'Five'],
#   ['Life After Life', '£26.13', 'In stock', 'Two'],
#   ['Letter to a Christian Nation', '£22.20', 'In stock', 'One'],
#   ["Let's Pretend This Never Happened: A Mostly True Memoir",
#    '£45.11',
#    'In stock',
#    'One'],
#   ['Legend (Legend #1)', '£43.69', 'In stock', 'Four'],
#   ['Lean In: Women, Work, and the Will to Lead', '£25.02', 'In stock', 'One'],
#   ["Lamb: The Gospel According to Biff, Christ's Childhood Pal",
#    '£55.50',
#    'In stock',
#    'Five'],
#   ['Lady Renegades (Rebel Belle #3)', '£53.04', 'In stock', 'Five'],
#   ['Jurassic Park (Jurassic Park #1)', '£44.97', 'In stock', 'One'],
#   ["It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond",
#    '£42.38',
#    'In stock',
#    'One'],
#   ['Is Everyone Hanging Out Without Me? (And Other Concerns)',
#    '£20.11',
#    'In stock',
#    'Three'],
#   ['Into the Wild', '£56.70', 'In stock', 'Five'],
#   ['Inferno (Robert Langdon #4)', '£41.00', 'In stock', 'Five'],
#   ["In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin",
#    '£28.85',
#    'In stock',
#    'Three'],
#   ['If I Run (If I Run #1)', '£49.97', 'In stock', 'Four'],
#   ["I've Got Your Number", '£19.69', 'In stock', 'One'],
#   ['I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban',
#    '£28.88',
#    'In stock',
#    'Two'],
#   ['Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World',
#    '£33.14',
#    'In stock',
#    'Three'],
#   ['House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth',
#    '£43.70',
#    'In stock',
#    'Two'],
#   ['House of Leaves', '£54.89', 'In stock', 'One'],
#   ['Horrible Bear!', '£37.52', 'In stock', 'Two'],
#   ['Holidays on Ice', '£51.07', 'In stock', 'Two'],
#   ['Heir to the Sky', '£44.07', 'In stock', 'Four'],
#   ['Green Eggs and Ham (Beginner Books B-16)', '£10.79', 'In stock', 'Four'],
#   ['Grayson, Vol 3: Nemesis (Grayson #3)', '£42.72', 'In stock', 'One'],
#   ['Gratitude', '£26.66', 'In stock', 'Five'],
#   ['Gone Girl', '£37.60', 'In stock', 'Five'],
#   ['Golden (Heart of Dread #3)', '£42.21', 'In stock', 'Four'],
#   ['Girl in the Blue Coat', '£46.83', 'In stock', 'Two'],
#   ['Fruits Basket, Vol. 3 (Fruits Basket #3)', '£45.17', 'In stock', 'Two'],
#   ['Friday Night Lights: A Town, a Team, and a Dream',
#    '£51.22',
#    'In stock',
#    'Three'],
#   ['Fire Bound (Sea Haven/Sisters of the Heart #5)',
#    '£21.28',
#    'In stock',
#    'Four'],
#   ['Fifty Shades Freed (Fifty Shades #3)', '£15.36', 'In stock', 'Five'],
#   ['Fellside', '£38.62', 'In stock', 'One'],
#   ['Extreme Prey (Lucas Davenport #26)', '£25.40', 'In stock', 'Three'],
#   ['Eragon (The Inheritance Cycle #1)', '£43.87', 'In stock', 'Three'],
#   ['Eclipse (Twilight #3)', '£18.74', 'In stock', 'One'],
#   ['Dune (Dune #1)', '£54.86', 'In stock', 'One'],
#   ['Dracula', '£52.62', 'In stock', 'Three'],
#   ['Do Androids Dream of Electric Sheep? (Blade Runner #1)',
#    '£51.48',
#    'In stock',
#    'One'],
#   ['Disrupted: My Misadventure in the Start-Up Bubble',
#    '£15.28',
#    'In stock',
#    'Five'],
#   ['Dead Wake: The Last Crossing of the Lusitania',
#    '£39.24',
#    'In stock',
#    'Five'],
#   ['David and Goliath: Underdogs, Misfits, and the Art of Battling Giants',
#    '£17.81',
#    'In stock',
#    'One'],
#   ['Darkfever (Fever #1)', '£56.02', 'In stock', 'One'],
#   ['Dark Places', '£23.90', 'In stock', 'Five'],
#   ['Crazy Rich Asians (Crazy Rich Asians #1)', '£49.13', 'In stock', 'Five'],
#   ['Counting Thyme', '£10.62', 'In stock', 'One'],
#   ['Cosmos', '£36.17', 'In stock', 'Two'],
#   ['Civilization and Its Discontents', '£59.95', 'In stock', 'Two'],
#   ['Cinder (The Lunar Chronicles #1)', '£26.09', 'In stock', 'One'],
#   ["Catastrophic Happiness: Finding Joy in Childhood's Messy Years",
#    '£37.35',
#    'In stock',
#    'Two'],
#   ['Career of Evil (Cormoran Strike #3)', '£24.72', 'In stock', 'Two'],
#   ['Breaking Dawn (Twilight #4)', '£35.28', 'In stock', 'Five'],
#   ['Brave Enough', '£51.32', 'In stock', 'Five'],
#   ['Boy Meets Boy', '£21.12', 'In stock', 'Three'],
#   ['Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen',
#    '£27.35',
#    'In stock',
#    'Two'],
#   ['Blink: The Power of Thinking Without Thinking',
#    '£21.74',
#    'In stock',
#    'Five'],
#   ['Black Flags: The Rise of ISIS', '£40.87', 'In stock', 'One'],
#   ['Black Butler, Vol. 1 (Black Butler #1)', '£49.31', 'In stock', 'One'],
#   ['Big Little Lies', '£22.11', 'In stock', 'One'],
#   ['Between Shades of Gray', '£20.79', 'In stock', 'Five'],
#   ["Best of My Love (Fool's Gold #20)", '£27.41', 'In stock', 'Two'],
#   ['Beowulf', '£38.35', 'In stock', 'Two'],
#   ['Beautiful Creatures (Caster Chronicles #1)', '£21.55', 'In stock', 'Five'],
#   ['Awkward', '£38.02', 'In stock', 'Two'],
#   ['Ash', '£22.06', 'In stock', 'Four'],
#   ['Are We There Yet?', '£10.66', 'In stock', 'Three'],
#   ['Are We Smart Enough to Know How Smart Animals Are?',
#    '£56.58',
#    'In stock',
#    'One'],
#   ['Annie on My Mind', '£36.83', 'In stock', 'Five'],
#   ['And Then There Were None', '£35.01', 'In stock', 'Two'],
#   ['A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#    '£30.48',
#    'In stock',
#    'Four'],
#   ['A Visit from the Goon Squad', '£14.08', 'In stock', 'Five'],
#   ['A Storm of Swords (A Song of Ice and Fire #3)',
#    '£31.22',
#    'In stock',
#    'Two'],
#   ['A Heartbreaking Work of Staggering Genius', '£54.29', 'In stock', 'Five'],
#   ['8 Keys to Mental Health Through Exercise', '£31.04', 'In stock', 'One'],
#   ['#GIRLBOSS', '£50.96', 'In stock', 'One'],
#   ['The Suffragettes (Little Black Classics, #96)',
#    '£11.89',
#    'In stock',
#    'Two'],
#   ['The Sense of an Ending', '£31.38', 'In stock', 'Three'],
#   ["The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)",
#    '£54.81',
#    'In stock',
#    'One'],
#   ['The Course of Love', '£16.78', 'In stock', 'Three'],
#   ['Sugar Rush (Offensive Line #2)', '£24.42', 'In stock', 'One'],
#   ['Saga, Volume 2 (Saga (Collected Editions) #2)',
#    '£11.75',
#    'In stock',
#    'Three'],
#   ['Run, Spot, Run: The Ethics of Keeping Pets', '£20.02', 'In stock', 'One'],
#   ['New Moon (Twilight #2)', '£12.86', 'In stock', 'Four'],
#   ['Life', '£31.58', 'In stock', 'Five'],
#   ["Kindle Paperwhite User's Guide", '£34.00', 'In stock', 'Three'],
#   ['H is for Hawk', '£57.42', 'In stock', 'Five'],
#   ['Girl Online On Tour (Girl Online #2)', '£53.47', 'In stock', 'One'],
#   ['Fruits Basket, Vol. 2 (Fruits Basket #2)', '£11.64', 'In stock', 'Five'],
#   ['Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)',
#    '£52.88',
#    'In stock',
#    'Four'],
#   ['Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)',
#    '£18.51',
#    'In stock',
#    'Four'],
#   ['While You Were Mine', '£41.32', 'In stock', 'Five'],
#   ['Where Lightning Strikes (Bleeding Stars #3)',
#    '£39.77',
#    'In stock',
#    'Three'],
#   ["When I'm Gone", '£51.96', 'In stock', 'Three'],
#   ['Ways of Seeing', '£39.51', 'In stock', 'Five'],
#   ['Vampire Knight, Vol. 1 (Vampire Knight #1)', '£15.40', 'In stock', 'One'],
#   ['Vampire Girl (Vampire Girl #1)', '£53.82', 'In stock', 'Two'],
#   ['Twenty Love Poems and a Song of Despair', '£30.95', 'In stock', 'Four'],
#   ['Travels with Charley: In Search of America', '£57.82', 'In stock', 'Five'],
#   ['Three Wishes (River of Time: California #1)', '£44.18', 'In stock', 'Two'],
#   ['This One Moment (Pushing Limits #1)', '£48.71', 'In stock', 'One'],
#   ['The Zombie Room', '£19.69', 'In stock', 'Five'],
#   ['The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)',
#    '£36.52',
#    'In stock',
#    'Two'],
#   ['The Tumor', '£41.56', 'In stock', 'Five'],
#   ['The Story of Hong Gildong', '£43.19', 'In stock', 'Four'],
#   ['The Silent Wife', '£12.34', 'In stock', 'Five'],
#   ['The Silent Twin (Detective Jennifer Knight #3)',
#    '£36.25',
#    'In stock',
#    'Three'],
#   ['The Selfish Gene', '£29.45', 'In stock', 'One'],
#   ['The Secret Healer', '£34.56', 'In stock', 'Three'],
#   ['The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)',
#    '£54.12',
#    'In stock',
#    'Three'],
#   ['The Republic', '£33.78', 'In stock', 'Three'],
#   ['The Odyssey', '£29.64', 'In stock', 'Three'],
#   ["The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)",
#    '£57.70',
#    'In stock',
#    'Four'],
#   ['The Nicomachean Ethics', '£36.34', 'In stock', 'One'],
#   ['The Name of the Wind (The Kingkiller Chronicle #1)',
#    '£50.59',
#    'In stock',
#    'Three'],
#   ['The Mirror & the Maze (The Wrath and the Dawn #1.5)',
#    '£29.38',
#    'In stock',
#    'One'],
#   ['The Little Prince', '£45.42', 'In stock', 'Two'],
#   ['The Light of the Fireflies', '£54.43', 'In stock', 'One'],
#   ['The Last Girl (The Dominion Trilogy #1)', '£36.26', 'In stock', 'Two'],
#   ['The Iliad', '£16.16', 'In stock', 'One'],
#   ['The Hook Up (Game On #1)', '£36.29', 'In stock', 'Five'],
#   ['The Haters', '£27.89', 'In stock', 'Five'],
#   ['The Girl You Lost', '£12.29', 'In stock', 'Five'],
#   ['The Girl In The Ice (DCI Erika Foster #1)', '£15.85', 'In stock', 'Three'],
#   ['The End of the Jesus Era (An Investigation #1)',
#    '£14.40',
#    'In stock',
#    'One'],
#   ['The Edge of Reason (Bridget Jones #2)', '£19.18', 'In stock', 'Four'],
#   ['The Complete Maus (Maus #1-2)', '£10.64', 'In stock', 'Three'],
#   ['The Communist Manifesto', '£14.76', 'In stock', 'Three'],
#   ['The Bhagavad Gita', '£57.49', 'In stock', 'Three'],
#   ['The Bette Davis Club', '£30.66', 'In stock', 'Three'],
#   ['The Art of Not Breathing', '£40.83', 'In stock', 'Four'],
#   ['Taking Shots (Assassins #1)', '£18.88', 'In stock', 'Two'],
#   ['Starlark', '£25.83', 'In stock', 'Three'],
#   ['Skip Beat!, Vol. 01 (Skip Beat! #1)', '£42.12', 'In stock', 'Three'],
#   ['Sister Sable (The Mad Queen #1)', '£13.33', 'In stock', 'Three'],
#   ['Shatter Me (Shatter Me #1)', '£42.40', 'In stock', 'One'],
#   ['Shameless', '£58.35', 'In stock', 'Three'],
#   ['Shadow Rites (Jane Yellowrock #10)', '£21.72', 'In stock', 'Four'],
#   ['Settling the Score (The Summer Games #1)', '£44.91', 'In stock', 'Two'],
#   ['Sense and Sensibility', '£37.46', 'In stock', 'One'],
#   ['Saga, Volume 1 (Saga (Collected Editions) #1)',
#    '£28.48',
#    'In stock',
#    'One'],
#   ['Rhythm, Chord & Malykhin', '£28.34', 'In stock', 'Two'],
#   ['Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',
#    '£46.96',
#    'In stock',
#    'Five'],
#   ['Paradise Lost (Paradise #1)', '£24.96', 'In stock', 'One'],
#   ['Paper Girls, Vol. 1 (Paper Girls #1-5)', '£21.71', 'In stock', 'Four'],
#   ['Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)',
#    '£29.87',
#    'In stock',
#    'Three'],
#   ['Origins (Alphas 0.5)', '£28.99', 'In stock', 'One'],
#   ['One Second (Seven #7)', '£52.94', 'In stock', 'Two'],
#   ['On the Road (Duluoz Legend)', '£32.36', 'In stock', 'Three'],
#   ["Old Records Never Die: One Man's Quest for His Vinyl and His Past",
#    '£55.66',
#    'In stock',
#    'Two'],
#   ['Off Sides (Off #1)', '£39.45', 'In stock', 'Five'],
#   ['Of Mice and Men', '£47.11', 'In stock', 'Two'],
#   ['Myriad (Prentor #1)', '£58.75', 'In stock', 'Four'],
#   ['My Perfect Mistake (Over the Top #1)', '£38.92', 'In stock', 'Two'],
#   ['Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',
#    '£39.39',
#    'In stock',
#    'Four'],
#   ['Meditations', '£25.89', 'In stock', 'Two'],
#   ['Matilda', '£28.34', 'In stock', 'One'],
#   ['Lost Among the Living', '£27.70', 'In stock', 'Four'],
#   ['Lord of the Flies', '£24.89', 'In stock', 'Three'],
#   ['Listen to Me (Fusion #1)', '£58.99', 'In stock', 'Three'],
#   ['Kitchens of the Great Midwest', '£57.20', 'In stock', 'Five'],
#   ['Jane Eyre', '£38.43', 'In stock', 'Five'],
#   ['Imperfect Harmony', '£34.74', 'In stock', 'Four'],
#   ['Icing (Aces Hockey #2)', '£40.44', 'In stock', 'Four'],
#   ['Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)',
#    '£45.24',
#    'In stock',
#    'Three'],
#   ["Having the Barbarian's Baby (Ice Planet Barbarians #7.5)",
#    '£34.96',
#    'In stock',
#    'Four'],
#   ['Giant Days, Vol. 1 (Giant Days #1-4)', '£56.76', 'In stock', 'Four'],
#   ['Fruits Basket, Vol. 1 (Fruits Basket #1)', '£40.28', 'In stock', 'Five'],
#   ['Frankenstein', '£38.00', 'In stock', 'Two'],
#   ['Forever Rockers (The Rocker #12)', '£28.80', 'In stock', 'Three'],
#   ['Fighting Fate (Fighting #6)', '£39.24', 'In stock', 'Three'],
#   ['Emma', '£32.93', 'In stock', 'Two'],
#   ['Eat, Pray, Love', '£51.32', 'In stock', 'Three'],
#   ['Deep Under (Walker Security #1)', '£47.09', 'In stock', 'Five'],
#   ["Choosing Our Religion: The Spiritual Lives of America's Nones",
#    '£28.42',
#    'In stock',
#    'Four'],
#   ['Charlie and the Chocolate Factory (Charlie Bucket #1)',
#    '£22.85',
#    'In stock',
#    'Three'],
#   ["Charity's Cross (Charles Towne Belles #4)", '£41.24', 'In stock', 'One'],
#   ['Bright Lines', '£39.07', 'In stock', 'Five'],
#   ["Bridget Jones's Diary (Bridget Jones #1)", '£29.82', 'In stock', 'One'],
#   ['Bounty (Colorado Mountain #7)', '£37.26', 'In stock', 'Four'],
#   ['Blood Defense (Samantha Brinkman #1)', '£20.30', 'In stock', 'Three'],
#   ['Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)',
#    '£34.65',
#    'In stock',
#    'Five'],
#   ['Beyond Good and Evil', '£43.38', 'In stock', 'One'],
#   ["Alice in Wonderland (Alice's Adventures in Wonderland #1)",
#    '£55.53',
#    'In stock',
#    'One'],
#   ['Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)',
#    '£57.06',
#    'In stock',
#    'Four'],
#   ["A Spy's Devotion (The Regency Spies of London #1)",
#    '£16.97',
#    'In stock',
#    'Five'],
#   ["1st to Die (Women's Murder Club #1)", '£53.98', 'In stock', 'One'],
#   ['1,000 Places to See Before You Die', '£26.08', 'In stock', 'Five']])

# %%
#Create a DataFrame
df = pd.DataFrame(data, columns=header)

# %%
#Clean column names
#df.columns = [col.replace(' ', '_').strip() for col in df.columns]
#df.columns = [col.replace('%', 'Percentage').strip() for col in df.columns]

# %%
df.head()
# Out:
#                                    Title   Price Availability Rating
# 0                   A Light in the Attic  £51.77     In stock  Three
# 1                     Tipping the Velvet  £53.74     In stock    One
# 2                             Soumission  £50.10     In stock    One
# 3                          Sharp Objects  £47.82     In stock   Four
# 4  Sapiens: A Brief History of Humankind  £54.23     In stock   Five

# %%
df.shape
# Out:
# (1000, 4)

# %%
def save_to_csv(df, filename=None):
    """
    Save the DataFrame to a CSV file
    """
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    if filename is None:
        filename = f"WebScrap_{timestamp}.csv"

    try:
        filename = f"{filename}_{timestamp}.csv"
        df.to_csv(filename, index=False, encoding='utf-8')
        print(f"Data saved to {filename}")
        return True
    except Exception as e:
        print(f"Error saving to CSV: {e}")
        return False

def save_to_excel(df, filename=None):
    """
    Save the DataFrame to an Excel file
    """
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    if filename is None:
        filename = f"WebScrap_{timestamp}.xlsx"

    try:
        filename = f"{filename}_{timestamp}.xlsx"
        df.to_excel(filename, index=False)
        print(f"Data saved to {filename}")
        return True
    except Exception as e:
        print(f"Error saving to Excel: {e}")
        return False

# %%
#Exporting the data in csv and excel format
save_to_csv(df, "books_to_scrape")
save_to_excel(df, "books_to_scrape")
# Out:
# Data saved to books_to_scrape_20260209_173950.csv
# Data saved to books_to_scrape_20260209_173950.xlsx
# True
